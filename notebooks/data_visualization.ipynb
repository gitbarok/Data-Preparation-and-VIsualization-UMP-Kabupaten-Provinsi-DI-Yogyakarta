# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                 12.01
# 6                 13.29
# 7                  4.37
# 8                  9.82
# 9                 10.14
# 10                 6.45
# 11                 3.40
# 12                12.11
# 13                 6.48
# 14                11.01
# 15                11.50
# 16                11.51
# 17                11.50
# 18                11.50
# 19                11.51
# 20                 8.25
# 21                 8.25
# 22                 8.25
# 23                 8.25
# 24                 8.25
# 25                 8.71
# 26                11.92
# 27                 8.71
# 28                 8.71
# 29                 8.71
# 30                 8.03
# 31                 4.94
# 32                 8.03
# 33                 8.03
# 34                 8.15
# 35                 8.51
# 36                 8.53
# 37                 8.53
# 38                 8.52
# 39                 8.42
# 40                 1.11
# 41                 0.81
# 42                 8.06
# 43                 3.11
# 44                 3.27
# 45                 7.59
# 46                 6.20
# 47                 3.12
# 48                 5.12
# 49                 4.08

# %%
data_sleman = df.query('Kabupaten == "Sleman"')
sns.set_style('darkgrid')
sns.lineplot(data=data_sleman, x="Tahun", y='Upah Minimum')
# Out:
# <AxesSubplot: xlabel='Tahun', ylabel='Upah Minimum'>

# %%
kabupaten_pivot = df.pivot('Tahun', 'Kabupaten', 'Upah Minimum')
kabupaten_pivot.head()
# Out:
# /var/folders/l5/0j6855hs3d98m4lrr_mnkbjc0000gn/T/ipykernel_883/2588233498.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   kabupaten_pivot = df.pivot('Tahun', 'Kabupaten', 'Upah Minimum')
# Kabupaten   Bantul  Gunungkidul  Kulonprogo   Sleman  Yogyakarta
# Tahun
# 2013        993484       947114      954339  1026181     1065247
# 2014       1125500       988500     1069000  1127000     1173300
# 2015       1163800      1108249     1138000  1200000     1302500
# 2016       1297700      1235700     1268870  1338000     1452400
# 2017       1404760      1337650     1373600  1448385     1572200

# %%
sns.lineplot(data=kabupaten_pivot)
# Out:
# <AxesSubplot: xlabel='Tahun'>

# %% [markdown]
# ### Visualization Minimum wage data for district in DI Yogyakarta with Linechart

# %%
fig, ax = plt.subplots(figsize = (10,5),)
sns.lineplot(data=df, x="Tahun", y='Upah Minimum', hue='Kabupaten')
plt.show()

# %% [markdown]
# Based on linechart above, it seems Yogyakarta District minimum wage always in rank 1, it is because yogyakarta district is the main capital of DI Yogyakarta

# %% [markdown]
# i feel like graph from seaborn is not very interactive, lets changed it with plotly

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
fig = px.line(
        df, x='Tahun', y='Upah Minimum', color='Kabupaten',
        title=f'Kenaikan Upah Minimum Kabupaten di Provinsi DI Yogyakarta Tahun 2013-2022')


fig.update_layout(title_x=0.5) 

# Format the y-axis tick labels
fig.update_layout(yaxis=dict(tickformat=',.0f', tickprefix='Rp ', title='Kenaikan Upah'))


# Display the chart
fig.show()

# %% [markdown]
# The visualization looks good and also very interactive when hover to the graph, now lets make cloroethmap for this data

# %%
import json

with open('../data/processed/yogyakarta.geojson') as f:
    district = json.load(f)

def chloropleth(year):
    """
        select year range 2013-2022, to create visualization on chloropleth map based on year.
    """
    fig = px.choropleth(
                df[df['Tahun']== year], geojson=district, color="Upah Minimum",
                locations="Kabupaten", featureidkey="properties.region", 
                color_continuous_scale=px.colors.sequential.Viridis_r, 
                hover_data={"Kabupaten":True, "Upah Minimum":':,'}
                )

    fig.update_geos(fitbounds="locations", visible=False)


    fig.update_layout(
            title=f"<b>Upah Minimum Kabupaten di Provinsi DI Yogyakarta<br>Tahun {year}</br>",
            title_x=0.5, title_y=0.95, title_font_size=22, title_font_family="Arial"
            )

    fig.update_layout(template='plotly_dark')

    return fig.show()


tahun_2013 = chloropleth(2013)
tahun_2013

    # Create cloroeth-map
